# %% [markdown]
# <a href="https://colab.research.google.com/github/kingabdullafn/poissonhw/blob/main/poissonhw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scipy.stats as stats
prob_1 = 1-stats.poisson.cdf(30,10)
print(prob_1)
prob2 = 1-stats.poisson.cdf(18,10) - stats.poisson.cdf(11,10)
print(prob2)
# Out:
# 7.983794658716903e-08
# -0.6895896416992517
